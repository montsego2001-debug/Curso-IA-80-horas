# %% [markdown]
# <a href="https://colab.research.google.com/github/montsego2001-debug/Curso-IA-80-horas/blob/main/Calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number1 = int(input("Inserta el número 1 : "))
number2 = int(input("Inserta el número 2 : "))

def sum(number1, number2):
  result = number1 + number2
  print(number1, "+", number2, "=", result)

def sub(number1, number2):
  result = number1 - number2
  print(number1, "-", number2, "=", result)

def mul(number1, number2):
  result = number1 * number2
  print(number1, "*", number2, "=", result)

def div(number1, number2):
  if number2 !=0:
    result = number1 / number2
    print(number1, "/", number2, "=", result)
  else:
    print("No se puede dividir entre 0")


def div_parte_entera(number1, number2):
  if number2 !=0:
    result = number1 // number2
    print(number1, "//", number2, "=", result)
  else:
    print("No se puede dividir entre 0")

#operador módulo es = resto de una división
def resto_div(number1, number2):
  result = number1 % number2
  print(number1, "%", number2, "=", result)


sum(number1, number2)
sub(number1, number2)
mul(number1, number2)
div(number1, number2)
div_parte_entera(number1, number2)
resto_div(number1, number2)
# Out:
# Inserta el número 1 : 8
# Inserta el número 2 : 5
# 8 + 5 = 13
# 8 - 5 = 3
# 8 * 5 = 40
# 8 / 5 = 1.6
# 8 // 5 = 1
# 8 % 5 = 3
